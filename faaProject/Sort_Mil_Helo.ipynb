# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("./acrftser.csv")

# %%
import re

list_heli = df['FSIS_MODEL'].unique()
list_heli_fixed=[]
for item in list_heli:
    list_heli_fixed.append(item.rstrip())

# %%
list_heli = pd.Series(list_heli_fixed)
list_heli_acft = pd.DataFrame(list_heli)
list_heli_acft
df = list_heli_acft[list_heli.str.contains('H')]
list_final = list_heli_acft[list_heli.str.contains('H')]
list_final=list_final[0].tolist()
list_final
#list_final= [x.strip(' ') for x in list_final]
# Out:
# ['J2MCCULH',
#  'S53H',
#  'HU16A',
#  'HU16B',
#  'ARROWFOH58A',
#  'ARROWFOH58A+',
#  'ARROWFOH58C',
#  'ARROWFUH1H',
#  'AT1OBHCAMRON',
#  'AT16HARVARD',
#  'SKYHAWK',
#  '7073H7C',
#  '7271H2',
#  '7272H3',
#  '7272H9',
#  '7372H3',
#  '7372H3C',
#  '7372H4',
#  '7372H4C',
#  '7372H5',
#  '7372H6',
#  '7372H6C',
#  '7372H7C',
#  '7373H4',
#  '7373H6',
#  '7373H9',
#  '7374H6',
#  '7375H3',
#  '7375H4',
#  '7375H6',
#  '7376H3',
#  '7377BH',
#  '7377H3',
#  '7377H4',
#  '7377HJ',
#  '7378EH',
#  '7378FH',
#  '7378H4',
#  '7378HX',
#  '7472H7B',
#  '7473H6',
#  '7474H6',
#  '7474HQF',
#  '7478HVF',
#  '76735H',
#  '76739H',
#  '7673JHF',
#  '77721H',
#  '7772H6',
#  '777FHT',
#  '11121AH',
#  'HS125700A',
#  '402CHAMP',
#  'UC43H',
#  '18ABEECH',
#  'C45H',
#  'H18',
#  'STC18BEECH',
#  'TC45H',
#  'BEECH',
#  'RC12H',
#  'UC12H',
#  'H35',
#  '400ABEECH',
#  'H50',
#  'RU21H',
#  'H90',
#  'FACH',
#  'HAWKER1000',
#  'HAWKER800',
#  'HAWKER800XP',
#  'AHIGGARLIK',
#  'BH125400A',
# ...

# %%
df = pd.read_csv("./Original_Datasets/Concatenated_Orig_data.csv")
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (3,4,5,10,11,12,13,14,15,16,17,18,20,26,28,29,32,33,34,35,39,40,41,42,43,44,45,47,48,49,50,51,57,58,59,60,61,62,63,64,65,66,68,69,70,71,72,73,74,75,76,77,78,81,82,104,106,111,112,113,134,178,179) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# 0                 AA1A
# 1                 182C
# 2                  150
# 3                 172M
# 4                 177B
#               ...
# 215303           SR22T
# 215304       PA-32-300
# 215305    CH601XLI SLS
# 215306       PA-44-180
# 215307           0-58B
# Name: c24, Length: 215308, dtype: object

# %%
df = df[df['c24'].isin(list_final)]
df['c24']
# Out:
# 13          7HC
# 19         182H
# 79         150H
# 97        369HS
# 108       369HS
#           ...
# 214824     150H
# 215169     172H
# 215172     150H
# 215233     172H
# 215273     206H
# Name: c24, Length: 5587, dtype: object

# %%
df.to_csv('./Original_Datasets/Helicopter_Orig_data.csv')
